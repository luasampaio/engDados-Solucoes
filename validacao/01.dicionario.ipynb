# %%
import numpy as np

# %%
my_dict = {'name': 'Luciana', 1: [2, 4, 3]}
print(my_dict)
# Out:
# {'name': 'Luciana', 1: [2, 4, 3]}

# %%
def DictToArray(d):
    """Convert dictionary values to numpy array"""
    #extract values and convert
    x=np.array(d.values())
    return x

# %%
dict = {'a': 1, 'b': 2, 'c': 3}

# %%
DictToArray(my_dict)
# Out:
# array(dict_values(['Luciana', [2, 4, 3]]), dtype=object)
