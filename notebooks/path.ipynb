# %%
import sys, os
print("CWD:", os.getcwd())
print("Tem 'src'?", os.path.exists("src"))
print("PYTHONPATH:", os.environ.get("PYTHONPATH"))
print("Primeiros sys.path:", sys.path[:3])
# Out:
# CWD: e:\engDados-Solucoes\notebooks
# Tem 'src'? False
# PYTHONPATH: src
# Primeiros sys.path: ['e:\\engDados-Solucoes\\notebooks\\src', 'C:\\Users\\luciana.santos\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\luciana.santos\\AppData\\Local\\Programs\\Python\\Python313\\DLLs']
