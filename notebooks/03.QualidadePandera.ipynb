# %% [markdown]
# - Função de processamento processar (robusta, com tratamento de divisão por zero)
#
# - Testes com pytest
#
# - Esquema opcional com Pandera (entrada/saída)
#
# - Funções simples de visualização com matplotlib (1 gráfico por função)

# %%
import sys, os
sys.path.insert(0, os.getcwd())
sys.path.append(os.path.join(os.getcwd(), "src"))

# %%
import pandas as pd
from src.processamento import processar
from src.visualizacao import plot_histograma, plot_series, plot_boxplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from src.processamento import processar
#       3 from src.visualizacao import plot_histograma, plot_series, plot_boxplot
#
# ModuleNotFoundError: No module named 'src'
