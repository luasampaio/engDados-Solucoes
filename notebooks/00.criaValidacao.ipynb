# %%
# Recriando o pacote "validacao" e ZIP após reset de estado

import pathlib, zipfile, datetime

BASE = pathlib.Path("/mnt/data/pacote-validacao")
ZIP = pathlib.Path("/mnt/data/pacote-validacao.zip")

def write(p: pathlib.Path, content: str):
    p.parent.mkdir(parents=True, exist_ok=True)
    p.write_text(content.strip() + "\n", encoding="utf-8")

readme = f"""
# Pacote de Validação (Pandera) — Português

Funções simples em **português** para validar DataFrames com **pandera**.

## Instalação
```bash
pip install pandera pandas
"""
