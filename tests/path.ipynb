# %%
import sys, os
print("CWD:", os.getcwd())
print("Tem 'src'?", os.path.exists("src"))
print("PYTHONPATH:", os.environ.get("PYTHONPATH"))
print("Primeiros sys.path:", sys.path[:3])
# Out:
# CWD: e:\engDados-Solucoes\tests
# Tem 'src'? False
# PYTHONPATH: src
# Primeiros sys.path: ['e:\\engDados-Solucoes\\tests\\src', 'c:\\Users\\luciana.santos\\AppData\\Local\\anaconda3\\python312.zip', 'c:\\Users\\luciana.santos\\AppData\\Local\\anaconda3\\DLLs']
