# %%
import os
print(os.getcwd())
# Out:
# e:\engDados-Solucoes

# %% [markdown]
# Confirmando o local do arquivo png

# %%
import os
print(os.path.exists("assets/dados_em_chamas_logo_hires.png"))
# Out:
# True

# %%
from PIL import Image

# Abrir logo
logo = Image.open('assets/dados_em_chamas_logo_hires.png')

# Redimensionar para 800x800
logo_resized = logo.resize((800, 800), Image.LANCZOS)
logo_resized.save('resizeLogo/logo_youtube2.png')

# %%
from PIL import Image

# Abrir logo
logo = Image.open('assets/dados_em_chamas_logo_hires.png')

# Redimensionar para 800x800
logo_resized = logo.resize((32, 32), Image.LANCZOS)
logo_resized.save('resizeLogo/Favicon.png')

# %%
from PIL import Image

# Abrir logo
logo = Image.open('assets/dados_em_chamas_logo_hires.png')

# Redimensionar para 800x800
logo_resized = logo.resize((460, 460), Image.LANCZOS)
logo_resized.save('resizeLogo/GitHub.png')

# %%
from PIL import Image

# Abrir logo
logo = Image.open('assets/dados_em_chamas_logo_hires.png')

# Redimensionar para 800x800
logo_resized = logo.resize((460, 460), Image.LANCZOS)
logo_resized.save('resizeLogo/GitHub.png')

# %%
logo = Image.open("assets/dados_em_chamas_logo_hires.png")
